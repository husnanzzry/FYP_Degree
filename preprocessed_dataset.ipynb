# %% [markdown]
# <a href="https://colab.research.google.com/github/husnanzzry/FYP_Degree/blob/main/preprocessed_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('new_cleaned_dataset.csv')

# %%
data.head()
# Out:
#    retweetCount DateCreated  \
# 0             3   29/1/2023
# 1            21    3/1/2023
# 2             0   18/1/2023
# 3             0    9/1/2023
# 4             0   16/1/2023
#
#                                         text_cleaned Bank_Name
# 0  it is best to use the maybank app the apps run...   Maybank
# 1  doqtahu mymaybank this must have malicious app...   Maybank
# 2  service bsn problem news is the daily light ma...   Maybank
# 3       maybank apps statement be 1 green and 99 red   Maybank
# 4              something wrong with maybank mae apps   Maybank

# %%
import nltk
nltk.download('punkt')  # download the punkt tokenizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data['text_tokenized'] = data['text_cleaned'].apply(nltk.word_tokenize)

# %%
data.head()
# Out:
#    retweetCount DateCreated  \
# 0             3   29/1/2023
# 1            21    3/1/2023
# 2             0   18/1/2023
# 3             0    9/1/2023
# 4             0   16/1/2023
#
#                                         text_cleaned Bank_Name  \
# 0  it is best to use the maybank app the apps run...   Maybank
# 1  doqtahu mymaybank this must have malicious app...   Maybank
# 2  service bsn problem news is the daily light ma...   Maybank
# 3       maybank apps statement be 1 green and 99 red   Maybank
# 4              something wrong with maybank mae apps   Maybank
#
#                                       text_tokenized
# 0  [it, is, best, to, use, the, maybank, app, the...
# 1  [doqtahu, mymaybank, this, must, have, malicio...
# 2  [service, bsn, problem, news, is, the, daily, ...
# 3  [maybank, apps, statement, be, 1, green, and, ...
# 4       [something, wrong, with, maybank, mae, apps]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = stopwords.words('english')

# %%
def remove_stop_words(text):
  words = text.split()
  filtered_words = [word for word in words if word not in stop_words]
  return ' '.join(filtered_words)

# %%
data['text_nostopwords'] = data['text_tokenized'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
data.head()
# Out:
#    retweetCount DateCreated  \
# 0             3   29/1/2023
# 1            21    3/1/2023
# 2             0   18/1/2023
# 3             0    9/1/2023
# 4             0   16/1/2023
#
#                                         text_cleaned Bank_Name  \
# 0  it is best to use the maybank app the apps run...   Maybank
# 1  doqtahu mymaybank this must have malicious app...   Maybank
# 2  service bsn problem news is the daily light ma...   Maybank
# 3       maybank apps statement be 1 green and 99 red   Maybank
# 4              something wrong with maybank mae apps   Maybank
#
#                                       text_tokenized  \
# 0  [it, is, best, to, use, the, maybank, app, the...
# 1  [doqtahu, mymaybank, this, must, have, malicio...
# 2  [service, bsn, problem, news, is, the, daily, ...
# 3  [maybank, apps, statement, be, 1, green, and, ...
# 4       [something, wrong, with, maybank, mae, apps]
#
#                                     text_nostopwords
# ...

# %%
"""import nltk
nltk.download('wordnet')
data['text_lemmatized'] = data['text_nostopwords'].apply(lambda x: [nltk.wordnet.WordNetLemmatizer().lemmatize(word) for word in x])"""
# Out:
# "import nltk\nnltk.download('wordnet')\ndata['text_lemmatized'] = data['text_nostopwords'].apply(lambda x: [nltk.wordnet.WordNetLemmatizer().lemmatize(word) for word in x])"

# %%
from nltk.stem import WordNetLemmatizer

# Download necessary resources
nltk.download('wordnet')

# Create WordNetLemmatizer instance
lemmatizer = WordNetLemmatizer()

# Define function to lemmatize tokens
def lemmatize(tokens):
    lemmatized_tokens = []
    for token in tokens:
        lemmatized_token = None
        for pos in ['n', 'v', 'a', 'r']:
            lemmatized_token = lemmatizer.lemmatize(token, pos=pos)
            if lemmatized_token != token:
                break
        lemmatized_tokens.append(lemmatized_token)
    return ' '.join(lemmatized_tokens)

# Apply lemmatization to the tokenized column
data['text_lemmatized'] = data['text_nostopwords'].apply(lemmatize)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data.head(10)
# Out:
#    retweetCount DateCreated  \
# 0             3   29/1/2023
# 1            21    3/1/2023
# 2             0   18/1/2023
# 3             0    9/1/2023
# 4             0   16/1/2023
# 5             1   27/1/2023
# 6             0   30/1/2023
# 7             0   29/1/2023
# 8             0   27/1/2023
# 9            19    2/1/2023
#
#                                         text_cleaned Bank_Name  \
# 0  it is best to use the maybank app the apps run...   Maybank
# 1  doqtahu mymaybank this must have malicious app...   Maybank
# 2  service bsn problem news is the daily light ma...   Maybank
# 3       maybank apps statement be 1 green and 99 red   Maybank
# 4              something wrong with maybank mae apps   Maybank
# 5  why are there even two apps in the first place...   Maybank
# 6  not me 122 am open maybank apps to check salar...   Maybank
# 7  i hear money coming in from maybank apps but n...   Maybank
# 8  every month maybank apps must make my blood ri...   Maybank
# ...

# %%
#from nltk.stem import PorterStemmer
#data['text_stemmed'] = data['text_lemmatized'].apply(lambda x: [PorterStemmer().stem(word) for word in x])

# %%
#data.head(10)

# %%
#data['text_preprocessed'] = data['text_lemmatized'].apply(lambda x: ' '.join(x))

# %%
#data.head()

# %%
df = pd.DataFrame(data)

# Save the dataframe to a CSV file
df.to_csv('preprocessed_dataset(3).csv', index=False)

# %%
data = pd.read_csv('new_cleaned_dataset.csv')

# %%
data.head()
# Out:
#    retweetCount DateCreated  \
# 0             3   29/1/2023
# 1            21    3/1/2023
# 2             0   18/1/2023
# 3             0    9/1/2023
# 4             0   16/1/2023
#
#                                         text_cleaned Bank_Name
# 0  it is best to use the maybank app the apps run...   Maybank
# 1  doqtahu mymaybank this must have malicious app...   Maybank
# 2  service bsn problem news is the daily light ma...   Maybank
# 3       maybank apps statement be 1 green and 99 red   Maybank
# 4              something wrong with maybank mae apps   Maybank
